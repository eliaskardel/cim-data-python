# %% [markdown]
# # Übung

# %% [markdown]
# * Iteriere über eine vorgegebene Eingabe-Liste von Zahlen
# * Enferne jedes dritte Element bis die Eingabe-Liste leer ist
# * Speichere die entfernten Zahlen in einer seperaten Liste und gebe diese am Schluss zurück
# * Ausgabe kann über die assert Funktion überprüft werden

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def remove_nums(int_list):
    result_list = [] 
    # add your logic here 
    
    # result_list = [30, 60, 90, 40, 80, 50, 20, 70, 10]
    return result_list

# %%
input = [10,20,30,40,50,60,70,80,90]

output = remove_nums(input)

assert output ==  [30, 60, 90, 40, 80, 50, 20, 70, 10]
print('Übung geschafft : ) ')
